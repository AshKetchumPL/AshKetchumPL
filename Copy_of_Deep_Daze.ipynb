# %% [markdown]
# <a href="https://colab.research.google.com/github/kotpolsa123/kotpolsa123/blob/main/Copy_of_Deep_Daze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-daze --upgrade
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 64 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 29.6 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=3267156b197a805368792b375d63a2976de1211bc5d4fd88ad59f13555384e7d
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# ...
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=10f4b5555613db76ec851881ccaa94d95ef7f049590b5d45096a378a0b592950
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
# Successfully built fire ftfy
# ...
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
# ...

# %%
from tqdm.notebook import trange
from IPython.display import Image, display
from deep_daze import Imagine

TEXT = 'an illustration of a minecraft house' #@param {type:"string"}
NUM_LAYERS = 32 #@param {type:"number"}
SAVE_EVERY =  20#@param {type:"number"}
IMAGE_WIDTH = 512 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 1e-5 #@param {type:"number"}
ITERATIONS = 1050 #@param {type:"number"}
save_gif = True #@param {type:"boolean"}

model = Imagine(
    text = TEXT,
    num_layers = NUM_LAYERS,
    save_every = SAVE_EVERY,
    image_width = IMAGE_WIDTH,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS,
    save_gif = save_gif
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(ITERATIONS, desc = 'iteration'):
        model.train_step(epoch, i)

        if i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./{filename}.jpg')
        display(image)
# Out:
# Setting jit to False because torch version is not 1.7.1.
# ...
# iteration:   0%|          | 0/1050 [00:00<?, ?it/s]
# image updated at "./an_illustration_of_a_minecraft_house.jpg"

# %%
# @title Download Video
#from google.colab import files
#files.download("video.mp4")
